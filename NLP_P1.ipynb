# %%
import nltk 
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
corpus=corpus = """Hello Welcome,to Krish Naik's NLP Tutorials.
Please do watch the entire course!
to become expert in NLP."""

sent_tokenize=sent_tokenize(corpus)

# %%
sent_tokenize
# Out:
# ["Hello Welcome,to Krish Naik's NLP Tutorials.",
#  'Please do watch the entire course!',
#  'to become expert in NLP.']

# %%
words=word_tokenize(corpus)

# %%
words
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
list=['study','plays','playing','goes']
from nltk.stem import PorterStemmer

# %%
st=PorterStemmer()
list2=[]
for word in list:
    list2.append(st.stem(word))

# %%
list2
# Out:
# ['studi', 'play', 'play', 'goe']

# %%
from nltk.stem import RegexpStemmer

# %%
reg=RegexpStemmer('ing$|es$|ed$',min=4)
for word in list:    
    print(reg.stem(word))
# Out:
# study
# plays
# play
# go

# %%
from nltk.stem import SnowballStemmer

# %%
sn=SnowballStemmer('english')

# %%
for word in list:    
    print(sn.stem(word))
# Out:
# studi
# play
# play
# goe

# %%
sn.stem('fairly')
# Out:
# 'fair'

# %%
from nltk.stem import WordNetLemmatizer

# %%
le=WordNetLemmatizer()

# %%
le.lemmatize('history',pos='n')
# Out:
# 'history'

# %%
from nltk.tokenize import word_tokenize

# %%
from nltk.corpus import stopwords
words=word_tokenize(corpus)
stopword=stopwords.words('english')

# %%
filtered_words=[]
for word in words:
    if word not in stopword:
        filtered_words.append(word)

# %%
print('word\troot\tsuffix')
list=['playing','plays']
for word in list:
    root=st.stem(word)
    if word.startswith(root):
        suffix=word[len(root):]
        if suffix=="":
            suffix='unknown'
        print(word,'\t',root,'\t',suffix)
# Out:
# word	root	suffix
# playing 	 play 	 ing
# plays 	 play 	 s

# %%
from nltk.tokenize import word_tokenize
corpus=corpus = """Hello Welcome,to Krish Naik's NLP Tutorials.
Please do watch the entire course!
to become expert in NLP."""

words=word_tokenize(corpus)

# %%
import nltk
pos_tags=nltk.pos_tag(words)

# %%
pos_tags
# Out:
# [('Hello', 'NNP'),
#  ('Welcome', 'NNP'),
#  (',', ','),
#  ('to', 'TO'),
#  ('Krish', 'NNP'),
#  ('Naik', 'NNP'),
#  ("'s", 'POS'),
#  ('NLP', 'NNP'),
#  ('Tutorials', 'NNP'),
#  ('.', '.'),
#  ('Please', 'NNP'),
#  ('do', 'VBP'),
#  ('watch', 'VB'),
#  ('the', 'DT'),
#  ('entire', 'JJ'),
#  ('course', 'NN'),
#  ('!', '.'),
#  ('to', 'TO'),
#  ('become', 'VB'),
#  ('expert', 'JJ'),
#  ('in', 'IN'),
#  ('NLP', 'NNP'),
#  ('.', '.')]

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\CHAIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
pip install svgling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
nltk.ne_chunk(pos_tags)
# Out:
# Tree('S', [Tree('PERSON', [('Hello', 'NNP')]), Tree('ORGANIZATION', [('Welcome', 'NNP')]), (',', ','), ('to', 'TO'), Tree('PERSON', [('Krish', 'NNP'), ('Naik', 'NNP')]), ("'s", 'POS'), Tree('ORGANIZATION', [('NLP', 'NNP'), ('Tutorials', 'NNP')]), ('.', '.'), ('Please', 'NNP'), ('do', 'VBP'), ('watch', 'VB'), ('the', 'DT'), ('entire', 'JJ'), ('course', 'NN'), ('!', '.'), ('to', 'TO'), ('become', 'VB'), ('expert', 'JJ'), ('in', 'IN'), Tree('ORGANIZATION', [('NLP', 'NNP')]), ('.', '.')])
